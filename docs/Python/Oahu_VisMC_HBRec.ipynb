# %% [markdown]
# ### WAMPO Mode Choice Model (HBW) - MNL

# %%
import pandas as pd
import numpy as np
import os
import larch
import caliperpy
from larch.roles import P,X
import subprocess
pd.set_option('display.max_columns', None)

# %%
# Open all files from appropriate folders
tazFile = "C:\\projects\\Oahu\\repo_new_model\\scenarios\\base_2022\\Output\\sedata\\scenario_se.bin"
survey_path = "C:\\projects\\Oahu\\repo_new_model\\docs\\data\\_private\\vis_survey\\output\\"
tripFile = survey_path + "vis_trips.csv"

skim_path = "C:\\projects\\Oahu\\repo_new_model\\docs\\data\\input\\skims\\"
autoSkim = skim_path + "Highway_AM.omx"
ptwalkSkim = skim_path + 'Walk_to_Bus.omx'
ptdriveSkim = skim_path + 'Drive_to_Bus.omx'
walkSkim = skim_path + 'Walk.omx'
bikeSkim = skim_path + 'Bike.omx'

# %%
dk = caliperpy.TransCAD.connect()
tazDF = dk.GetDataFrameFromBin(tazFile)
caliperpy.TransCAD.disconnect()

tripDF = pd.read_csv(tripFile)
# Out:
# Connecting to TransCAD...
# Disconnected from TransCAD!

# %%
# Open omx file(s)
autoSkimFile = larch.OMX(autoSkim)
ptwalkSkimFile = larch.OMX(ptwalkSkim)
# ptdriveSkimFile = larch.OMX(ptdriveSkim)
walkSkimFile = larch.OMX(walkSkim)
bikeSkimFile = larch.OMX(bikeSkim)

zoneIDs = autoSkimFile.TAZ[:]

taz_alt_map = {zoneIDs[i]: i for i in range(len(zoneIDs))}

# %%
# Select only the relevant recorsds
estDF = tripDF[(tripDF["mode"] != "other") & (tripDF["mode"].notnull())]
# print(pd.unique(estDF["mode"]))

# %%
# Create the intrazonal and business indicators
estDF['IZ'] = estDF['iz_flag']
estDF['business_flag'] = np.select([estDF['visitor_type'] == "business"], [1], 0)
# Out:
# C:\Users\Kyle\AppData\Local\Temp\ipykernel_30968\4080613111.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   estDF['IZ'] = estDF['iz_flag']
# C:\Users\Kyle\AppData\Local\Temp\ipykernel_30968\4080613111.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   estDF['business_flag'] = np.select([estDF['visitor_type'] == "business"], [1], 0)

# %%
# Attach the (free-flow) skims based on Orig_TAZ and Dest_TAZ
estDF['OTAZIndex'] = estDF['o_taz'].map(taz_alt_map)
origIdxs = estDF['OTAZIndex'].to_numpy()

estDF['DTAZIndex'] = estDF['d_taz'].map(taz_alt_map)
destIdxs = estDF['DTAZIndex'].to_numpy()
# Out:
# C:\Users\Kyle\AppData\Local\Temp\ipykernel_30968\3995184942.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   estDF['OTAZIndex'] = estDF['o_taz'].map(taz_alt_map)
# C:\Users\Kyle\AppData\Local\Temp\ipykernel_30968\3995184942.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   estDF['DTAZIndex'] = estDF['d_taz'].map(taz_alt_map)

# %%
# Highway skims
estDF['AutoTime'] = pd.DataFrame(data = autoSkimFile['Time'][:][origIdxs, destIdxs], index = estDF.index)
estDF['DriveDist'] = pd.DataFrame(data = autoSkimFile['Distance'][:][origIdxs, destIdxs], index = estDF.index)

# Walk skims
estDF['WalkTime'] = pd.DataFrame(data = walkSkimFile['Time'][:][origIdxs, destIdxs], index = estDF.index)
estDF['WalkDist'] = pd.DataFrame(data = walkSkimFile['Distance'][:][origIdxs, destIdxs], index = estDF.index)

# Bike skims
estDF['BikeTime'] = pd.DataFrame(data = bikeSkimFile['Time'][:][origIdxs, destIdxs], index = estDF.index)
estDF['BikeDist'] = pd.DataFrame(data = bikeSkimFile['Distance'][:][origIdxs, destIdxs], index = estDF.index)

# Public transit skims
estDF['PT_TotalTime'] = pd.DataFrame(data = ptwalkSkimFile['Total Time'][:][origIdxs, destIdxs], index = estDF.index)
estDF['Fare'] = pd.DataFrame(data = ptwalkSkimFile['Fare'][:][origIdxs, destIdxs], index = estDF.index)
estDF['AccessWalkTime'] = pd.DataFrame(data = ptwalkSkimFile['Access Walk Time'][:][origIdxs, destIdxs], index = estDF.index)
estDF['EgressWalkTime'] = pd.DataFrame(data = ptwalkSkimFile['Egress Walk Time'][:][origIdxs, destIdxs], index = estDF.index)
estDF['PT_IVTT'] = pd.DataFrame(data = ptwalkSkimFile['In-Vehicle Time'][:][origIdxs, destIdxs], index = estDF.index)
estDF['InitWaitTime'] = pd.DataFrame(data = ptwalkSkimFile['Initial Wait Time'][:][origIdxs, destIdxs], index = estDF.index)
estDF['N_Transfers'] = pd.DataFrame(data = ptwalkSkimFile['Number of Transfers'][:][origIdxs, destIdxs], index = estDF.index)
# Out:
# C:\Users\Kyle\AppData\Local\Temp\ipykernel_30968\1004122564.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   estDF['AutoTime'] = pd.DataFrame(data = autoSkimFile['Time'][:][origIdxs, destIdxs], index = estDF.index)
# C:\Users\Kyle\AppData\Local\Temp\ipykernel_30968\1004122564.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   estDF['DriveDist'] = pd.DataFrame(data = autoSkimFile['Distance'][:][origIdxs, destIdxs], index = estDF.index)
# C:\Users\Kyle\AppData\Local\Temp\ipykernel_30968\1004122564.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   estDF['WalkTime'] = pd.DataFrame(data = walkSkimFile['Time'][:][origIdxs, destIdxs], index = estDF.index)
# C:\Users\Kyle\AppData\Local\Temp\ipykernel_30968\1004122564.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   estDF['WalkDist'] = pd.DataFrame(data = walkSkimFile['Distance'][:][origIdxs, destIdxs], index = estDF.index)
# C:\Users\Kyle\AppData\Local\Temp\ipykernel_30968\1004122564.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   estDF['BikeTime'] = pd.DataFrame(data = bikeSkimFile['Time'][:][origIdxs, destIdxs], index = estDF.index)
# C:\Users\Kyle\AppData\Local\Temp\ipykernel_30968\1004122564.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   estDF['BikeDist'] = pd.DataFrame(data = bikeSkimFile['Distance'][:][origIdxs, destIdxs], index = estDF.index)
# C:\Users\Kyle\AppData\Local\Temp\ipykernel_30968\1004122564.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   estDF['PT_TotalTime'] = pd.DataFrame(data = ptwalkSkimFile['Total Time'][:][origIdxs, destIdxs], index = estDF.index)
# C:\Users\Kyle\AppData\Local\Temp\ipykernel_30968\1004122564.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   estDF['Fare'] = pd.DataFrame(data = ptwalkSkimFile['Fare'][:][origIdxs, destIdxs], index = estDF.index)
# C:\Users\Kyle\AppData\Local\Temp\ipykernel_30968\1004122564.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   estDF['AccessWalkTime'] = pd.DataFrame(data = ptwalkSkimFile['Access Walk Time'][:][origIdxs, destIdxs], index = estDF.index)
# C:\Users\Kyle\AppData\Local\Temp\ipykernel_30968\1004122564.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   estDF['EgressWalkTime'] = pd.DataFrame(data = ptwalkSkimFile['Egress Walk Time'][:][origIdxs, destIdxs], index = estDF.index)
# C:\Users\Kyle\AppData\Local\Temp\ipykernel_30968\1004122564.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   estDF['PT_IVTT'] = pd.DataFrame(data = ptwalkSkimFile['In-Vehicle Time'][:][origIdxs, destIdxs], index = estDF.index)
# C:\Users\Kyle\AppData\Local\Temp\ipykernel_30968\1004122564.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   estDF['InitWaitTime'] = pd.DataFrame(data = ptwalkSkimFile['Initial Wait Time'][:][origIdxs, destIdxs], index = estDF.index)
# C:\Users\Kyle\AppData\Local\Temp\ipykernel_30968\1004122564.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   estDF['N_Transfers'] = pd.DataFrame(data = ptwalkSkimFile['Number of Transfers'][:][origIdxs, destIdxs], index = estDF.index)

# %%
estDF.head(5)
# Out:
#      SAMPN  weight visitor_type  party            deptime            arrtime  \
# 0  1000149   34.41     personal      1   9/1/2011 9:00:00  9/1/2011 10:00:00
# 1  1000149   34.41     personal      1  9/1/2011 13:00:00  9/1/2011 14:30:00
# 2  1000149   34.41     personal      1  9/1/2011 16:00:00  9/1/2011 17:00:00
# 3  1000150   68.82     personal      1   9/1/2011 7:00:00  9/1/2011 11:00:00
# 4  1000150   68.82     personal      1  9/1/2011 15:00:00  9/1/2011 16:00:00
#
#    mode      o_purp      d_purp  o_taz  d_taz o_ptype d_ptype  pa_flag  p_taz  \
# 0  auto        home        shop    659    400    home   other        1    659
# 1  auto        shop  recreation    400     33   other   other        1    400
# 2  auto  recreation        home     33    659   other    home        0    659
# 3   tnc        home  recreation   1106   1106   other   other        1   1106
# 4   tnc  recreation        home   1106    636   other   other        0    636
#
#    a_taz  iz_flag p_purp      a_purp trip_purp  auto_time  auto_distance  \
# 0    400        0   home        shop    HBShop  20.832300      15.986400
# 1     33        0   shop  recreation       NHB  23.592100      18.141800
# 2     33        0   home  recreation     HBRec   5.942140       2.611840
# 3   1106        1   home  recreation     HBRec   0.711835       0.358312
# 4   1106        0   home  recreation     HBRec  24.473500      14.603800
#
#    bike_time  bike_distance  walk_time  walk_distance  bus_gen_cost  bus_fare  \
# 0   76.92430      15.384900  369.23700      15.384900       37.6930   2.04000
# 1   89.40520      17.881000  429.14500      17.881000       54.3256   1.18164
# 2   13.05920       2.611840   62.68420       2.611840       21.5707   0.68000
# 3    1.79156       0.358312    8.59949       0.358312           NaN       NaN
# 4   71.65790      14.331600  343.95800      14.331600       43.8649   1.36000
#
#    bus_ivtt  bus_init_wait  bus_xfer_wait  bus_init_pen_time  \
# 0  35.18670        2.50000           12.5                0.0
# 1  55.34290        8.11475           15.0                0.0
# 2   7.53239        5.00000            0.0                0.0
# 3       NaN            NaN            NaN                NaN
# 4  28.05230       15.00000           10.0                0.0
#
#    bus_xfer_pen_time  bus_xfer_walk_time  bus_access_walk_time  \
# 0               10.0                 0.0               5.95639
# 1               10.0                 0.0               7.54887
# 2                0.0                 0.0               7.41075
# 3                NaN                 NaN                   NaN
# 4                5.0                 0.0               3.13801
#
#    bus_egress_walk_time  bus_dwell_time  bus_total_time  bus_num_xfers  \
# 0               7.54887         14.5000         88.1919            2.0
# 1              13.31840         25.2869        134.6120            2.0
# 2              14.84370          8.0000         42.7869            0.0
# 3                   NaN             NaN             NaN            NaN
# 4              15.59080         20.0000         96.7811            1.0
#
#    bus_iv_distance  bus_length  bus_walk_time  IZ  business_flag  OTAZIndex  \
# 0         16.60890    17.17160       412.1190   0              0        655
# 1         28.71360    29.58310       709.9940   0              0        396
# 2          2.34968     3.27695        78.6467   0              0         32
# 3              NaN         NaN            NaN   1              0       1102
# 4         14.52620    15.30650       367.3570   0              0       1102
#
#    DTAZIndex   AutoTime  DriveDist    WalkTime   WalkDist   BikeTime  \
# 0        396  20.832270  15.986408  369.236603  15.384860  76.924324
# 1         32  23.592121  18.141794  429.144775  17.881035  89.405190
# 2        655   7.163401   3.082613   73.677696   3.069904  15.349521
# 3       1102   0.711835   0.358312    8.599492   0.358312   1.791561
# 4        632  24.430613  14.534485  344.739899  14.364161  71.820839
#
#     BikeDist  PT_TotalTime          Fare  AccessWalkTime  EgressWalkTime  \
# 0  15.384860  8.819194e+01  2.040000e+00    5.956390e+00    7.548872e+00
# 1  17.881035  1.346119e+02  1.181639e+00    7.548872e+00    1.331844e+01
# 2   3.069904  4.415821e+01  6.800000e-01    1.297353e+01    7.410750e+00
# 3   0.358312 -3.402823e+38 -3.402823e+38   -3.402823e+38   -3.402823e+38
# 4  14.364161  9.111428e+01  6.800000e-01    1.559076e+01    4.588924e+00
#
#         PT_IVTT  InitWaitTime   N_Transfers
# 0  3.518668e+01  2.500000e+00  2.000000e+00
# 1  5.534293e+01  8.114754e+00  2.000000e+00
# 2  7.773936e+00  7.500000e+00  0.000000e+00
# 3 -3.402823e+38 -3.402823e+38 -3.402823e+38
# 4  2.687799e+01  6.509433e+00  1.000000e+00

# %%
estDF['AutoTime'] = estDF['AutoTime'].apply(lambda x: 9999 if np.isclose(x, -3.40285e+38, atol = 100) else x)
estDF['DriveDist'] = estDF['DriveDist'].apply(lambda x: 9999 if np.isclose(x, -3.40285e+38, atol = 100) else x)
estDF['WalkTime'] = estDF['WalkTime'].apply(lambda x: 9999 if np.isclose(x, -3.40285e+38, atol = 100) else x)
estDF['WalkDist'] = estDF['WalkDist'].apply(lambda x: 9999 if np.isclose(x, -3.40285e+38, atol = 100) else x)
estDF['BikeTime'] = estDF['BikeTime'].apply(lambda x: 9999 if np.isclose(x, -3.40285e+38, atol = 100) else x)
estDF['BikeDist'] = estDF['BikeDist'].apply(lambda x: 9999 if np.isclose(x, -3.40285e+38, atol = 100) else x)
estDF['PT_TotalTime'] = estDF['PT_TotalTime'].apply(lambda x: 9999 if np.isclose(x, -3.40285e+38, atol = 100) else x)
estDF['PT_IVTT'] = estDF['PT_IVTT'].apply(lambda x: 9999 if np.isclose(x, -3.40285e+38, atol = 100) else x)
estDF['Fare'] = estDF['Fare'].apply(lambda x: 9999 if np.isclose(x, -3.40285e+38, atol = 100) else x)
estDF['InitWaitTime'] = estDF['InitWaitTime'].apply(lambda x: 9999 if np.isclose(x, -3.40285e+38, atol = 100) else x)
estDF['N_Transfers'] = estDF['N_Transfers'].apply(lambda x: 9999 if np.isclose(x, -3.40285e+38, atol = 100) else x)
estDF['AccessWalkTime'] = estDF['AccessWalkTime'].apply(lambda x: 9999 if np.isclose(x, -3.40285e+38, atol = 100) else x)
estDF['EgressWalkTime'] = estDF['EgressWalkTime'].apply(lambda x: 9999 if np.isclose(x, -3.40285e+38, atol = 100) else x)
# Out:
# C:\Users\Kyle\AppData\Local\Temp\ipykernel_30968\1836316654.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   estDF['AutoTime'] = estDF['AutoTime'].apply(lambda x: 9999 if np.isclose(x, -3.40285e+38, atol = 100) else x)
# C:\Users\Kyle\AppData\Local\Temp\ipykernel_30968\1836316654.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   estDF['DriveDist'] = estDF['DriveDist'].apply(lambda x: 9999 if np.isclose(x, -3.40285e+38, atol = 100) else x)
# C:\Users\Kyle\AppData\Local\Temp\ipykernel_30968\1836316654.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   estDF['WalkTime'] = estDF['WalkTime'].apply(lambda x: 9999 if np.isclose(x, -3.40285e+38, atol = 100) else x)
# C:\Users\Kyle\AppData\Local\Temp\ipykernel_30968\1836316654.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   estDF['WalkDist'] = estDF['WalkDist'].apply(lambda x: 9999 if np.isclose(x, -3.40285e+38, atol = 100) else x)
# C:\Users\Kyle\AppData\Local\Temp\ipykernel_30968\1836316654.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   estDF['BikeTime'] = estDF['BikeTime'].apply(lambda x: 9999 if np.isclose(x, -3.40285e+38, atol = 100) else x)
# C:\Users\Kyle\AppData\Local\Temp\ipykernel_30968\1836316654.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   estDF['BikeDist'] = estDF['BikeDist'].apply(lambda x: 9999 if np.isclose(x, -3.40285e+38, atol = 100) else x)
# C:\Users\Kyle\AppData\Local\Temp\ipykernel_30968\1836316654.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   estDF['PT_TotalTime'] = estDF['PT_TotalTime'].apply(lambda x: 9999 if np.isclose(x, -3.40285e+38, atol = 100) else x)
# C:\Users\Kyle\AppData\Local\Temp\ipykernel_30968\1836316654.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   estDF['PT_IVTT'] = estDF['PT_IVTT'].apply(lambda x: 9999 if np.isclose(x, -3.40285e+38, atol = 100) else x)
# C:\Users\Kyle\AppData\Local\Temp\ipykernel_30968\1836316654.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   estDF['Fare'] = estDF['Fare'].apply(lambda x: 9999 if np.isclose(x, -3.40285e+38, atol = 100) else x)
# C:\Users\Kyle\AppData\Local\Temp\ipykernel_30968\1836316654.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   estDF['InitWaitTime'] = estDF['InitWaitTime'].apply(lambda x: 9999 if np.isclose(x, -3.40285e+38, atol = 100) else x)
# C:\Users\Kyle\AppData\Local\Temp\ipykernel_30968\1836316654.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   estDF['N_Transfers'] = estDF['N_Transfers'].apply(lambda x: 9999 if np.isclose(x, -3.40285e+38, atol = 100) else x)
# C:\Users\Kyle\AppData\Local\Temp\ipykernel_30968\1836316654.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   estDF['AccessWalkTime'] = estDF['AccessWalkTime'].apply(lambda x: 9999 if np.isclose(x, -3.40285e+38, atol = 100) else x)
# C:\Users\Kyle\AppData\Local\Temp\ipykernel_30968\1836316654.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   estDF['EgressWalkTime'] = estDF['EgressWalkTime'].apply(lambda x: 9999 if np.isclose(x, -3.40285e+38, atol = 100) else x)

# %%
# Add relevant HH fields
# estDF = pd.merge(estDF, hhDF[['ID', 'HHSize', 'Vehicles', 'Income', 'CommercialVehicles', 'WorkersEmployed']], left_on = 'HouseholdID', right_on = 'ID')
# estDF.head()

# %%
# Attach relevant TAZ demographics
# First on origins
estDF = pd.merge(estDF, tazDF[['TAZ', 'AreaType']], left_on = 'o_taz', right_on = 'TAZ')
estDF.rename(columns={'AreaType':'O_AreaType'}, inplace=True)
estDF.drop(['TAZ'], axis=1, inplace=True)
estDF.head()
# Out:
#      SAMPN  weight visitor_type  party            deptime            arrtime  \
# 0  1000149   34.41     personal      1   9/1/2011 9:00:00  9/1/2011 10:00:00
# 1  1000161  204.39     personal      2  9/1/2011 15:45:00  9/1/2011 16:00:00
# 2  1000167  116.79     personal      2  9/1/2011 11:00:00  9/1/2011 11:10:00
# 3  1000167  116.79     personal      6  9/1/2011 19:30:00  9/1/2011 19:45:00
# 4  1000183   49.15     personal      1   9/1/2011 7:00:00  9/1/2011 10:00:00
#
#    mode o_purp    d_purp  o_taz  d_taz o_ptype d_ptype  pa_flag  p_taz  a_taz  \
# 0  auto   home      shop    659    400    home   other        1    659    400
# 1  walk    eat      home    659    637   other    home        0    637    659
# 2  walk   shop      home    659    672   other    home        0    672    659
# 3  walk    eat      home    659    672   other    home        0    672    659
# 4  walk   home  business    659    659   other   other        1    659    659
#
#    iz_flag p_purp    a_purp trip_purp  auto_time  auto_distance  bike_time  \
# 0        0   home      shop    HBShop  20.832300      15.986400  76.924300
# 1        0   home       eat     HBEat   2.129680       1.089020   4.886310
# 2        0   home      shop    HBShop   1.217140       0.592204   2.687490
# 3        0   home       eat     HBEat   1.217140       0.592204   2.687490
# 4        1   home  business       HBW   0.374445       0.177754   0.888772
#
#    bike_distance  walk_time  walk_distance  bus_gen_cost  bus_fare   bus_ivtt  \
# 0      15.384900  369.23700      15.384900      37.69300      2.04  35.186700
# 1       0.977263   23.45430       0.977263      14.07480      0.68   1.404980
# 2       0.537498   12.90000       0.537498       7.38739      0.68   0.578031
# 3       0.537498   12.90000       0.537498       7.38739      0.68   0.578031
# 4       0.177754    4.26611       0.177754           NaN       NaN        NaN
#
#    bus_init_wait  bus_xfer_wait  bus_init_pen_time  bus_xfer_pen_time  \
# 0         2.5000           12.5                0.0               10.0
# 1         2.5000            0.0                0.0                0.0
# 2         2.2093            0.0                0.0                0.0
# 3         2.2093            0.0                0.0                0.0
# 4            NaN            NaN                NaN                NaN
#
#    bus_xfer_walk_time  bus_access_walk_time  bus_egress_walk_time  \
# 0                 0.0               5.95639               7.54887
# 1                 0.0              11.58000               5.95639
# 2                 0.0               1.57743               5.95639
# 3                 0.0               1.57743               5.95639
# 4                 NaN                   NaN                   NaN
#
#    bus_dwell_time  bus_total_time  bus_num_xfers  bus_iv_distance  bus_length  \
# 0            14.5         88.1919            2.0        16.608900   17.171600
# 1             3.0         24.4414            0.0         0.585406    1.316090
# 2             2.0         12.3212            0.0         0.240846    0.554756
# 3             2.0         12.3212            0.0         0.240846    0.554756
# 4             NaN             NaN            NaN              NaN         NaN
#
#    bus_walk_time  IZ  business_flag  OTAZIndex  DTAZIndex   AutoTime  \
# 0       412.1190   0              0        655        396  20.832270
# 1        31.5861   0              0        655        633   1.485524
# 2        13.3141   0              0        655        668   1.727376
# 3        13.3141   0              0        655        668   1.727376
# 4            NaN   1              0        655        655   0.374445
#
#    DriveDist    WalkTime   WalkDist   BikeTime   BikeDist  PT_TotalTime  \
# 0  15.986408  369.236603  15.384860  76.924324  15.384860     88.191940
# 1   0.677653   16.263664   0.677653   3.388264   0.677653     24.941362
# 2   0.776877   17.169113   0.715380   3.576898   0.715380     12.111856
# 3   0.776877   17.169113   0.715380   3.576898   0.715380     12.111856
# 4   0.177754    4.266106   0.177754   0.888772   0.177754   9999.000000
#
#       Fare  AccessWalkTime  EgressWalkTime      PT_IVTT  InitWaitTime  \
# 0     2.04         5.95639        7.548872    35.186680           2.5
# 1     0.68         5.95639       11.579997     1.404975           2.5
# 2     0.68         5.95639        1.577434     0.578031           2.0
# 3     0.68         5.95639        1.577434     0.578031           2.0
# 4  9999.00      9999.00000     9999.000000  9999.000000        9999.0
#
#    N_Transfers O_AreaType
# 0          2.0   Downtown
# 1          0.0   Downtown
# 2          0.0   Downtown
# 3          0.0   Downtown
# 4       9999.0   Downtown

# %%
# Then on destinations
estDF = pd.merge(estDF, tazDF[['TAZ', 'AreaType']], left_on = 'd_taz', right_on = 'TAZ')
estDF.rename(columns={'AreaType':'D_AreaType'}, inplace=True)
estDF.drop(['TAZ'], axis=1, inplace=True)
estDF.head()
# Out:
#      SAMPN  weight visitor_type  party            deptime            arrtime  \
# 0  1000149   34.41     personal      1   9/1/2011 9:00:00  9/1/2011 10:00:00
# 1  1001269   83.41     personal      4  1/1/2000 18:00:00  1/1/2000 18:01:00
# 2  1000755   34.61     personal      1  1/1/2000 12:30:00  1/1/2000 12:31:00
# 3  1000161  204.39     personal      2  9/1/2011 15:45:00  9/1/2011 16:00:00
# 4  1000190   18.08     business      1   9/1/2011 9:30:00   9/1/2011 9:39:00
#
#    mode      o_purp d_purp  o_taz  d_taz o_ptype d_ptype  pa_flag  p_taz  \
# 0  auto        home   shop    659    400    home   other        1    659
# 1  auto        home   shop    636    400    home   other        1    636
# 2  auto  recreation    eat      1    400   other   other        1      1
# 3  walk         eat   home    659    637   other    home        0    637
# 4  walk  recreation   home    659    637   other    home        0    637
#
#    a_taz  iz_flag      p_purp      a_purp trip_purp  auto_time  auto_distance  \
# 0    400        0        home        shop    HBShop   20.83230       15.98640
# 1    400        0        home        shop    HBShop   19.56930       15.46270
# 2    400        0  recreation         eat       NHB   29.74400       20.14980
# 3    659        0        home         eat     HBEat    2.12968        1.08902
# 4    659        0        home  recreation     HBRec    2.12968        1.08902
#
#    bike_time  bike_distance  walk_time  walk_distance  bus_gen_cost  bus_fare  \
# 0   76.92430      15.384900   369.2370      15.384900       37.6930      2.04
# 1   74.37040      14.874100   356.9780      14.874100       36.0051      1.36
# 2   92.39840      18.479700   443.5120      18.479700           NaN       NaN
# 3    4.88631       0.977263    23.4543       0.977263       14.0748      0.68
# 4    4.88631       0.977263    23.4543       0.977263       14.0748      0.68
#
#    bus_ivtt  bus_init_wait  bus_xfer_wait  bus_init_pen_time  \
# 0  35.18670            2.5           12.5                0.0
# 1  32.33190           15.0           10.0                0.0
# 2       NaN            NaN            NaN                NaN
# 3   1.40498            2.5            0.0                0.0
# 4   1.40498            2.5            0.0                0.0
#
#    bus_xfer_pen_time  bus_xfer_walk_time  bus_access_walk_time  \
# 0               10.0                 0.0               5.95639
# 1                5.0                 0.0               3.13801
# 2                NaN                 NaN                   NaN
# 3                0.0                 0.0              11.58000
# 4                0.0                 0.0              11.58000
#
#    bus_egress_walk_time  bus_dwell_time  bus_total_time  bus_num_xfers  \
# 0               7.54887            14.5         88.1919            2.0
# 1               4.29225            15.0         84.7621            1.0
# 2                   NaN             NaN             NaN            NaN
# 3               5.95639             3.0         24.4414            0.0
# 4               5.95639             3.0         24.4414            0.0
#
#    bus_iv_distance  bus_length  bus_walk_time  IZ  business_flag  OTAZIndex  \
# 0        16.608900    17.17160       412.1190   0              0        655
# 1        20.450900    20.76050       498.2520   0              0        632
# 2              NaN         NaN            NaN   0              0          0
# 3         0.585406     1.31609        31.5861   0              0        655
# 4         0.585406     1.31609        31.5861   0              1        655
#
#    DTAZIndex   AutoTime  DriveDist    WalkTime   WalkDist   BikeTime  \
# 0        396  20.832270  15.986408  369.236603  15.384860  76.924324
# 1        396  19.569260  15.462737  356.977509  14.874064  74.370354
# 2        396  29.744041  20.149845  443.512207  18.479675  92.398376
# 3        633   1.485524   0.677653   16.263664   0.677653   3.388264
# 4        633   1.485524   0.677653   16.263664   0.677653   3.388264
#
#     BikeDist  PT_TotalTime     Fare  AccessWalkTime  EgressWalkTime  \
# 0  15.384860     88.191940     2.04        5.956390        7.548872
# 1  14.874064     84.762146     1.36        3.138008        4.292253
# 2  18.479675   9999.000000  9999.00     9999.000000     9999.000000
# 3   0.677653     24.941362     0.68        5.956390       11.579997
# 4   0.677653     24.941362     0.68        5.956390       11.579997
#
#        PT_IVTT  InitWaitTime  N_Transfers O_AreaType D_AreaType
# 0    35.186680           2.5          2.0   Downtown   Suburban
# 1    32.331890          15.0          1.0   Downtown   Suburban
# 2  9999.000000        9999.0       9999.0      Rural   Suburban
# 3     1.404975           2.5          0.0   Downtown      Rural
# 4     1.404975           2.5          0.0   Downtown      Rural

# %%
# Attach the relevant TAZ accessibilities
# First on origins
# estDF = pd.merge(estDF, accDF[['ZONE', 'TransitStopDensity', 'WalkIndex', 'JobsHousingDiversity', 'JobMixDiversity', 'TransitAccessibilityToJobsAM']], left_on = 'HHTAZ', right_on = 'ZONE')
# estDF.rename(columns={'TransitStopDensity':'O_TransitStopDensity', 'WalkIndex':'O_WalkIndex', 'JobsHousingDiversity':'O_JobsHousingDiversity', 'JobMixDiversity':'O_JobMixDiversity', 'TransitAccessibilityToJobsAM': 'O_TransitAccessibilityToJobsAM'}, inplace=True)
# estDF.drop(['ZONE'], axis=1, inplace=True)
# estDF.head()

# %%
# Then on destinations
# estDF = pd.merge(estDF, accDF[['ZONE', 'TransitStopDensity', 'WalkIndex', 'JobsHousingDiversity', 'JobMixDiversity', 'TransitAccessibilityToJobsAM']], left_on = 'WorkTAZ', right_on = 'ZONE')
# estDF.rename(columns={'TransitStopDensity':'D_TransitStopDensity', 'WalkIndex':'D_WalkIndex', 'JobsHousingDiversity':'D_JobsHousingDiversity', 'JobMixDiversity':'D_JobMixDiversity', 'TransitAccessibilityToJobsAM': 'D_TransitAccessibilityToJobsAM'}, inplace=True)
# estDF.drop(['ZONE'], axis=1, inplace=True)
# estDF.head()

# %%
# Drop records when PT was chosen but not available
estDF = estDF[~((estDF["mode"] == "bus") & (estDF["PT_IVTT"] == 9999))]

# %%
estDF.describe()
# Out:
#               SAMPN       weight        party        o_taz        d_taz  \
# count  4.319000e+03  4319.000000  4319.000000  4319.000000  4319.000000
# mean   1.001399e+06   102.231547     2.062283   636.846955   637.208613
# std    5.933335e+02    91.908810     9.729960   222.304263   221.434724
# min    1.000149e+06     7.900000     1.000000     1.000000     1.000000
# 25%    1.000907e+06    49.150000     1.000000   636.000000   636.000000
# 50%    1.001463e+06    79.360000     1.000000   664.000000   664.000000
# 75%    1.001910e+06   117.670000     2.000000   680.000000   680.000000
# max    1.002349e+06   642.340000   360.000000  1116.000000  1116.000000
#
#            pa_flag        p_taz        a_taz      iz_flag    auto_time  \
# count  4319.000000  4319.000000  4319.000000  4319.000000  4281.000000
# mean      0.700857   641.116694   632.938875     0.157675     7.909776
# std       0.457936   205.083511   237.402390     0.364479    12.393238
# min       0.000000     1.000000     1.000000     0.000000     0.114406
# 25%       0.000000   636.000000   635.000000     0.000000     1.033680
# 50%       1.000000   667.000000   659.000000     0.000000     2.216000
# 75%       1.000000   676.000000   680.000000     0.000000     7.941960
# max       1.000000  1116.000000  1116.000000     1.000000    81.533500
#
#        auto_distance    bike_time  bike_distance    walk_time  walk_distance  \
# count    4281.000000  4281.000000    4281.000000  4281.000000    4281.000000
# mean        5.128238    24.722859       4.944572   118.669720       4.944572
# std         8.936654    43.015753       8.603151   206.475619       8.603151
# min         0.066737     0.333685       0.066737     1.601690       0.066737
# 25%         0.490982     2.454910       0.490982    11.783600       0.490982
# 50%         1.114420     5.566250       1.113250    26.718000       1.113250
# 75%         4.273690    20.046100       4.009220    96.221300       4.009220
# max        53.366200   246.531000      49.306200  1183.350000      49.306200
#
#        bus_gen_cost     bus_fare     bus_ivtt  bus_init_wait  bus_xfer_wait  \
# count   3410.000000  3410.000000  3410.000000    3410.000000    3410.000000
# mean      20.129782     0.747848    12.802978       5.755306       2.342064
# std       17.800013     0.220315    23.551914       4.951966       4.781546
# min        4.462860     0.680000     0.116924       2.000000       0.000000
# 25%        7.757380     0.680000     0.604836       2.244900       0.000000
# 50%       12.463600     0.680000     2.039980       2.500000       0.000000
# 75%       26.222375     0.680000    13.031100       7.500000       0.000000
# max      110.433000     2.040000   159.141000      30.000000      20.000000
#
#        bus_init_pen_time  bus_xfer_pen_time  bus_xfer_walk_time  \
# count             3410.0        3410.000000         3410.000000
# mean                 0.0           1.324002            0.287874
# std                  0.0           2.623218            1.106283
# min                  0.0           0.000000            0.000000
# 25%                  0.0           0.000000            0.000000
# 50%                  0.0           0.000000            0.000000
# 75%                  0.0           0.000000            0.000000
# max                  0.0          10.000000           15.376300
#
#        bus_access_walk_time  bus_egress_walk_time  bus_dwell_time  \
# count           3410.000000           3410.000000     3410.000000
# mean               7.029792              7.329487        6.341327
# std                8.083911              7.660033        7.898936
# min                0.929531              0.675964        0.500000
# 25%                2.138350              2.796000        1.000000
# 50%                3.838430              5.478070        3.000000
# 75%                7.410750              7.410750        8.500000
# max               44.840600             44.840600       58.000000
#
#        bus_total_time  bus_num_xfers  bus_iv_distance   bus_length  \
# count     3410.000000    3410.000000      3410.000000  3410.000000
# mean        43.212828       0.264800         6.064115     6.674414
# std         45.917985       0.524644        12.022006    12.332617
# min          6.678480       0.000000         0.048718     0.235859
# 25%         12.430000       0.000000         0.240846     0.595706
# 50%         21.985850       0.000000         0.762174     1.316090
# 75%         55.581150       0.000000         5.000020     5.654208
# max        283.553000       2.000000        84.599300    87.222400
#
#        bus_walk_time           IZ  business_flag    OTAZIndex    DTAZIndex  \
# count    3410.000000  4319.000000    4319.000000  4319.000000  4319.000000
# mean      160.185832     0.157675       0.143552   633.104885   633.465849
# std       295.982813     0.364479       0.350675   221.658065   220.787818
# min         5.660610     0.000000       0.000000     0.000000     0.000000
# 25%        14.296900     0.000000       0.000000   632.000000   632.000000
# 50%        31.586100     0.000000       0.000000   660.000000   660.000000
# 75%       135.700500     0.000000       0.000000   676.000000   676.000000
# max      2093.340000     1.000000       1.000000  1112.000000  1112.000000
#
#           AutoTime    DriveDist     WalkTime     WalkDist     BikeTime  \
# count  4319.000000  4319.000000  4319.000000  4319.000000  4319.000000
# mean     72.717137    69.925507   183.079409    69.750675    89.460020
# std     802.027482   802.205737   819.498671   802.216289   801.734595
# min       0.114406     0.066737     1.601686     0.066737     0.333685
# 25%       0.991574     0.473661    11.367853     0.473661     2.368303
# 50%       2.169288     1.089016    25.617416     1.067392     5.336962
# 75%       8.417055     4.556380   100.302261     4.179261    20.896306
# max    9999.000000  9999.000000  9999.000000  9999.000000  9999.000000
#
#           BikeDist  PT_TotalTime         Fare  AccessWalkTime  EgressWalkTime  \
# count  4319.000000   4319.000000  4319.000000     4319.000000     4319.000000
# mean     69.750675   2117.957276  2084.198382     2089.541283     2089.112766
# std     802.216289   4044.155077  4061.271484     4058.536504     4058.755406
# min       0.066737      6.678485     0.680000        0.868469        0.675964
# 25%       0.473661     13.964836     0.680000        3.088051        2.900010
# 50%       1.067392     33.472069     0.680000        5.956390        5.956390
# 75%       4.179261    143.967178     1.360000       25.354368       25.354368
# max    9999.000000   9999.000000  9999.000000     9999.000000     9999.000000
#
#            PT_IVTT  InitWaitTime  N_Transfers
# count  4319.000000   4319.000000  4319.000000
# mean   2093.719743   2088.392686  2083.814249
# std    4056.439469   4059.121925  4061.468613
# min       0.116924      2.000000     0.000000
# 25%       0.862498      2.244898     0.000000
# 50%       5.056063      6.500000     0.000000
# 75%      56.662859     15.000000     1.000000
# max    9999.000000   9999.000000  9999.000000

# %%
# Larch requires the chosen options be integers
conditions = [
    estDF['mode'] == 'auto',
    estDF['mode'] == 'bus',
    estDF['mode'] == 'tnc',
    estDF['mode'] == 'walk',
    estDF['mode'] == 'bike'
]

values = [1, 2, 3, 4, 5]

estDF['mode'] = np.select(conditions, values, default = -1)

# Finally, filter the estimation table to just the current trip purpose
# 'HBShop', 'NHB', 'HBEat', 'HBRec', 'HBO', 'HBW'
estDF = estDF[(estDF['trip_purp'] == 'HBRec')]

# %%
# Create Larch Dataframe from selected data and instantiate larch model using data
auto = 1
bus = 2
tnc = 3
walk = 4
bike = 5

dfs = larch.DataFrames(co = estDF, 
                       alt_codes = [auto, bus, tnc, walk, bike], 
                       alt_names = ['auto', 'bus', 'tnc', 'walk', 'bike'], 
                       ch_name = 'mode',
                       av = 1)

# Create Larch Model
m = larch.Model(dataservice=dfs)

# Define Title
m.title = "Oahu Visitor Mode Choice - All Trips"

# Choice
m.choice_co_code = 'mode'

# Availability

# %%
m.utility_co[auto] = (
    + P.ASC_auto
    + P.Time * X('AutoTime')
    + P.BusiFlag * X('business_flag')
)

m.utility_co[bus] = (
    + P.ASC_bus
    + P.Time * X('PT_IVTT')
    + P.Fare * X('Fare')
    # + P.Transfers * X('N_Transfers')
    # + P.InitialWaitTime * X('InitWaitTime')
    # + P.AccessEgressTimes * X('AccessWalkTime + EgressWalkTime')
    + P.AccessEgressInitWaitTimes * X('AccessWalkTime + InitWaitTime + EgressWalkTime')
)

m.utility_co[tnc] = (
    + P.Time * X('AutoTime')
    + P.BusiFlag * X('business_flag')
)

m.utility_co[walk] = (
    + P.ASC_walk
    + P.Time_NM * X('WalkTime')
    + P.IZ * X('IZ')
    + P.CBD * X('O_AreaType == "Downtown"') * X('D_AreaType == "Downtown"')
)

m.utility_co[bike] = (
    + P.ASC_bike
    + P.Time_NM * X('BikeTime')
    + P.CBD * X('O_AreaType == "Downtown"') * X('D_AreaType == "Downtown"')
    # + P.IZ * X('IZ')
    # + P.JobsHousingDiversity * X('O_JobsHousingDiversity')
    # + P.JobMixDiversity * X('O_JobMixDiversity')
)

m.lock_values(Time = -0.025)

# %%
m.load_data()
# Out:
# req_data does not request avail_ca or avail_co but it is set and being provided
# converting data_co to <class 'numpy.float64'>

# %%
m.dataframes.choice_avail_summary()
# Out:
#                             name  chosen available
# 1                           auto   286.0     920.0
# 2                            bus    64.0     920.0
# 3                            tnc   150.0     920.0
# 4                           walk   418.0     920.0
# 5                           bike     2.0     920.0
# < Total All Alternatives >         920.0

# %%
m.dataframes.data_co.statistics()
# Out:
#                                                       n   minimum  maximum  \
# (O_AreaType == "Downtown")*(D_AreaType == "Down...  920  0.000000      1.0
# AccessWalkTime + InitWaitTime + EgressWalkTime      920  5.185331  29997.0
# AutoTime                                            920  0.114406   9999.0
# BikeTime                                            920  0.333685   9999.0
# Fare                                                920  0.680000   9999.0
# IZ                                                  920  0.000000      1.0
# PT_IVTT                                             920  0.145665   9999.0
# WalkTime                                            920  1.601686   9999.0
# business_flag                                       920  0.000000      1.0
#
#                                                        median  \
# (O_AreaType == "Downtown")*(D_AreaType == "Down...   0.000000
# AccessWalkTime + InitWaitTime + EgressWalkTime      21.899591
# AutoTime                                             4.485202
# BikeTime                                            10.210425
# Fare                                                 0.680000
# IZ                                                   0.000000
# PT_IVTT                                             10.226222
# WalkTime                                            49.010044
# business_flag                                        0.000000
#
#                                                                                             histogram  \
# (O_AreaType == "Downtown")*(D_AreaType == "Down...  [[[<Element '{http://www.w3.org/1999/02/22-rdf...
# AccessWalkTime + InitWaitTime + EgressWalkTime      [[[<Element '{http://www.w3.org/1999/02/22-rdf...
# AutoTime                                            [[[<Element '{http://www.w3.org/1999/02/22-rdf...
# BikeTime                                            [[[<Element '{http://www.w3.org/1999/02/22-rdf...
# Fare                                                [[[<Element '{http://www.w3.org/1999/02/22-rdf...
# IZ                                                  [[[<Element '{http://www.w3.org/1999/02/22-rdf...
# PT_IVTT                                             [[[<Element '{http://www.w3.org/1999/02/22-rdf...
# WalkTime                                            [[[<Element '{http://www.w3.org/1999/02/22-rdf...
# business_flag                                       [[[<Element '{http://www.w3.org/1999/02/22-rdf...
#
#                                                            mean         stdev  \
# (O_AreaType == "Downtown")*(D_AreaType == "Down...     0.416304      0.492945
# AccessWalkTime + InitWaitTime + EgressWalkTime      5692.167475  11738.109935
# AutoTime                                              98.984986    927.353205
# BikeTime                                             124.971922    926.349309
# Fare                                                1891.765578   3915.416280
# IZ                                                     0.122826      0.328237
# PT_IVTT                                             1906.475617   3908.388778
# WalkTime                                             269.463488    947.099829
# business_flag                                          0.122826      0.328237
#
#                                                     zeros  positives  \
# (O_AreaType == "Downtown")*(D_AreaType == "Down...    537        383
# AccessWalkTime + InitWaitTime + EgressWalkTime          0        920
# AutoTime                                                0        920
# BikeTime                                                0        920
# Fare                                                    0        920
# IZ                                                    807        113
# PT_IVTT                                                 0        920
# WalkTime                                                0        920
# business_flag                                         807        113
#
#                                                     negatives  \
# (O_AreaType == "Downtown")*(D_AreaType == "Down...          0
# AccessWalkTime + InitWaitTime + EgressWalkTime              0
# AutoTime                                                    0
# BikeTime                                                    0
# Fare                                                        0
# IZ                                                          0
# PT_IVTT                                                     0
# WalkTime                                                    0
# business_flag                                               0
#
#                                                     nonzero_minimum  \
# (O_AreaType == "Downtown")*(D_AreaType == "Down...         1.000000
# AccessWalkTime + InitWaitTime + EgressWalkTime             5.185331
# AutoTime                                                   0.114406
# BikeTime                                                   0.333685
# Fare                                                       0.680000
# IZ                                                         1.000000
# PT_IVTT                                                    0.145665
# WalkTime                                                   1.601686
# business_flag                                              1.000000
#
#                                                     nonzero_maximum  \
# (O_AreaType == "Downtown")*(D_AreaType == "Down...              1.0
# AccessWalkTime + InitWaitTime + EgressWalkTime              29997.0
# AutoTime                                                     9999.0
# BikeTime                                                     9999.0
# Fare                                                         9999.0
# IZ                                                              1.0
# PT_IVTT                                                      9999.0
# WalkTime                                                     9999.0
# business_flag                                                   1.0
#
#                                                     nonzero_mean  \
# (O_AreaType == "Downtown")*(D_AreaType == "Down...      1.000000
# AccessWalkTime + InitWaitTime + EgressWalkTime       5692.167475
# AutoTime                                               98.984986
# BikeTime                                              124.971922
# Fare                                                 1891.765578
# IZ                                                      1.000000
# PT_IVTT                                              1906.475617
# WalkTime                                              269.463488
# business_flag                                           1.000000
#
#                                                     nonzero_stdev
# (O_AreaType == "Downtown")*(D_AreaType == "Down...       0.000000
# AccessWalkTime + InitWaitTime + EgressWalkTime       11738.109935
# AutoTime                                               927.353205
# BikeTime                                               926.349309
# Fare                                                  3915.416280
# IZ                                                       0.000000
# PT_IVTT                                               3908.388778
# WalkTime                                               947.099829
# business_flag                                            0.000000

# %%
# Run MLE
m.set_cap(cap=100.0)
m.maximize_loglike(method='SLSQP', maxiter=1000)

# Order output parameters
m.ordering = [
        ("ASCs", 'ASC.*',),
        ("LOS", 'B_.*',),
]

# Calculate Stats
m.calculate_parameter_covariance()
# Out:
# <h3>Iteration 029 [Optimization terminated successfully] </h3>
# <p>Best LL = -2450.5560031681216</p>
#                               value  initvalue  nullvalue  minimum  maximum  \
# ASC_auto                   0.645358      0.000      0.000 -100.000  100.000
# ASC_bike                  -4.123085      0.000      0.000 -100.000  100.000
# ASC_bus                    0.704619      0.000      0.000 -100.000  100.000
# ASC_walk                   1.943425      0.000      0.000 -100.000  100.000
# AccessEgressInitWaitTimes -0.022516      0.000      0.000 -100.000  100.000
# BusiFlag                   0.199479      0.000      0.000 -100.000  100.000
# CBD                        1.581274      0.000      0.000 -100.000  100.000
# Fare                      -0.756407      0.000      0.000 -100.000  100.000
# IZ                         0.527566      0.000      0.000 -100.000  100.000
# Time                      -0.025000     -0.025     -0.025   -0.025   -0.025
# Time_NM                   -0.024943      0.000      0.000 -100.000  100.000
#
#                            holdfast note      best
# ASC_auto                          0       0.645358
# ASC_bike                          0      -4.123085
# ASC_bus                           0       0.704619
# ASC_walk                          0       1.943425
# AccessEgressInitWaitTimes         0      -0.022516
# BusiFlag                          0       0.199479
# CBD                               0       1.581274
# Fare                              0      -0.756407
# IZ                                0       0.527566
# Time                              1      -0.025000
# Time_NM                           0      -0.024943

# %%
m.parameter_summary()
# Out:
# <style type="text/css">
# #T_0da10 th {
#   vertical-align: top;
#   text-align: left;
# }
# #T_0da10 td {
#   vertical-align: top;
#   text-align: left;
# }
# #T_0da10_row0_col0, #T_0da10_row0_col1, #T_0da10_row0_col2, #T_0da10_row0_col3, #T_0da10_row0_col4, #T_0da10_row1_col0, #T_0da10_row1_col1, #T_0da10_row1_col2, #T_0da10_row1_col3, #T_0da10_row1_col4, #T_0da10_row2_col0, #T_0da10_row2_col1, #T_0da10_row2_col2, #T_0da10_row2_col3, #T_0da10_row2_col4, #T_0da10_row3_col0, #T_0da10_row3_col1, #T_0da10_row3_col2, #T_0da10_row3_col3, #T_0da10_row3_col4, #T_0da10_row4_col0, #T_0da10_row4_col1, #T_0da10_row4_col2, #T_0da10_row4_col3, #T_0da10_row4_col4, #T_0da10_row5_col0, #T_0da10_row5_col1, #T_0da10_row5_col2, #T_0da10_row5_col3, #T_0da10_row5_col4, #T_0da10_row6_col0, #T_0da10_row6_col1, #T_0da10_row6_col2, #T_0da10_row6_col3, #T_0da10_row6_col4, #T_0da10_row7_col0, #T_0da10_row7_col1, #T_0da10_row7_col2, #T_0da10_row7_col3, #T_0da10_row7_col4, #T_0da10_row8_col0, #T_0da10_row8_col1, #T_0da10_row8_col2, #T_0da10_row8_col3, #T_0da10_row8_col4, #T_0da10_row9_col0, #T_0da10_row9_col1, #T_0da10_row9_col2, #T_0da10_row9_col3, #T_0da10_row9_col4, #T_0da10_row10_col0, #T_0da10_row10_col1, #T_0da10_row10_col2, #T_0da10_row10_col3, #T_0da10_row10_col4 {
#   font-family: monospace;
# }
# </style>
# <table id="T_0da10">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0da10_level0_col0" class="col_heading level0 col0" >Value</th>
#       <th id="T_0da10_level0_col1" class="col_heading level0 col1" >Std Err</th>
#       <th id="T_0da10_level0_col2" class="col_heading level0 col2" >t Stat</th>
#       <th id="T_0da10_level0_col3" class="col_heading level0 col3" >Signif</th>
#       <th id="T_0da10_level0_col4" class="col_heading level0 col4" >Null Value</th>
#       <th id="T_0da10_level0_col5" class="col_heading level0 col5" >Constrained</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Category</th>
#       <th class="index_name level1" >Parameter</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0da10_level0_row0" class="row_heading level0 row0" rowspan="4">ASCs</th>
#       <th id="T_0da10_level1_row0" class="row_heading level1 row0" >ASC_auto</th>
#       <td id="T_0da10_row0_col0" class="data row0 col0" > 0.645</td>
#       <td id="T_0da10_row0_col1" class="data row0 col1" > 0.101</td>
#       <td id="T_0da10_row0_col2" class="data row0 col2" > 6.40</td>
#       <td id="T_0da10_row0_col3" class="data row0 col3" >***</td>
#       <td id="T_0da10_row0_col4" class="data row0 col4" > 0.00</td>
#       <td id="T_0da10_row0_col5" class="data row0 col5" ></td>
#     </tr>
#     <tr>
#       <th id="T_0da10_level1_row1" class="row_heading level1 row1" >ASC_bike</th>
#       <td id="T_0da10_row1_col0" class="data row1 col0" >-4.12</td>
#       <td id="T_0da10_row1_col1" class="data row1 col1" > 0.720</td>
#       <td id="T_0da10_row1_col2" class="data row1 col2" >-5.73</td>
#       <td id="T_0da10_row1_col3" class="data row1 col3" >***</td>
#       <td id="T_0da10_row1_col4" class="data row1 col4" > 0.00</td>
#       <td id="T_0da10_row1_col5" class="data row1 col5" ></td>
#     </tr>
#     <tr>
#       <th id="T_0da10_level1_row2" class="row_heading level1 row2" >ASC_bus</th>
#       <td id="T_0da10_row2_col0" class="data row2 col0" > 0.705</td>
#       <td id="T_0da10_row2_col1" class="data row2 col1" > 0.483</td>
#       <td id="T_0da10_row2_col2" class="data row2 col2" > 1.46</td>
#       <td id="T_0da10_row2_col3" class="data row2 col3" ></td>
#       <td id="T_0da10_row2_col4" class="data row2 col4" > 0.00</td>
#       <td id="T_0da10_row2_col5" class="data row2 col5" ></td>
#     </tr>
#     <tr>
#       <th id="T_0da10_level1_row3" class="row_heading level1 row3" >ASC_walk</th>
#       <td id="T_0da10_row3_col0" class="data row3 col0" > 1.94</td>
#       <td id="T_0da10_row3_col1" class="data row3 col1" > 0.177</td>
#       <td id="T_0da10_row3_col2" class="data row3 col2" > 11.00</td>
#       <td id="T_0da10_row3_col3" class="data row3 col3" >***</td>
#       <td id="T_0da10_row3_col4" class="data row3 col4" > 0.00</td>
#       <td id="T_0da10_row3_col5" class="data row3 col5" ></td>
#     </tr>
#     <tr>
#       <th id="T_0da10_level0_row4" class="row_heading level0 row4" rowspan="7">Other</th>
#       <th id="T_0da10_level1_row4" class="row_heading level1 row4" >AccessEgressInitWaitTimes</th>
#       <td id="T_0da10_row4_col0" class="data row4 col0" >-0.0225</td>
#       <td id="T_0da10_row4_col1" class="data row4 col1" > 0.0108</td>
#       <td id="T_0da10_row4_col2" class="data row4 col2" >-2.09</td>
#       <td id="T_0da10_row4_col3" class="data row4 col3" >*</td>
#       <td id="T_0da10_row4_col4" class="data row4 col4" > 0.00</td>
#       <td id="T_0da10_row4_col5" class="data row4 col5" ></td>
#     </tr>
#     <tr>
#       <th id="T_0da10_level1_row5" class="row_heading level1 row5" >BusiFlag</th>
#       <td id="T_0da10_row5_col0" class="data row5 col0" > 0.199</td>
#       <td id="T_0da10_row5_col1" class="data row5 col1" > 0.281</td>
#       <td id="T_0da10_row5_col2" class="data row5 col2" > 0.71</td>
#       <td id="T_0da10_row5_col3" class="data row5 col3" ></td>
#       <td id="T_0da10_row5_col4" class="data row5 col4" > 0.00</td>
#       <td id="T_0da10_row5_col5" class="data row5 col5" ></td>
#     </tr>
#     <tr>
#       <th id="T_0da10_level1_row6" class="row_heading level1 row6" >CBD</th>
#       <td id="T_0da10_row6_col0" class="data row6 col0" > 1.58</td>
#       <td id="T_0da10_row6_col1" class="data row6 col1" > 0.208</td>
#       <td id="T_0da10_row6_col2" class="data row6 col2" > 7.60</td>
#       <td id="T_0da10_row6_col3" class="data row6 col3" >***</td>
#       <td id="T_0da10_row6_col4" class="data row6 col4" > 0.00</td>
#       <td id="T_0da10_row6_col5" class="data row6 col5" ></td>
#     </tr>
#     <tr>
#       <th id="T_0da10_level1_row7" class="row_heading level1 row7" >Fare</th>
#       <td id="T_0da10_row7_col0" class="data row7 col0" >-0.756</td>
#       <td id="T_0da10_row7_col1" class="data row7 col1" > 0.548</td>
#       <td id="T_0da10_row7_col2" class="data row7 col2" >-1.38</td>
#       <td id="T_0da10_row7_col3" class="data row7 col3" ></td>
#       <td id="T_0da10_row7_col4" class="data row7 col4" > 0.00</td>
#       <td id="T_0da10_row7_col5" class="data row7 col5" ></td>
#     </tr>
#     <tr>
#       <th id="T_0da10_level1_row8" class="row_heading level1 row8" >IZ</th>
#       <td id="T_0da10_row8_col0" class="data row8 col0" > 0.528</td>
#       <td id="T_0da10_row8_col1" class="data row8 col1" > 0.322</td>
#       <td id="T_0da10_row8_col2" class="data row8 col2" > 1.64</td>
#       <td id="T_0da10_row8_col3" class="data row8 col3" ></td>
#       <td id="T_0da10_row8_col4" class="data row8 col4" > 0.00</td>
#       <td id="T_0da10_row8_col5" class="data row8 col5" ></td>
#     </tr>
#     <tr>
#       <th id="T_0da10_level1_row9" class="row_heading level1 row9" >Time</th>
#       <td id="T_0da10_row9_col0" class="data row9 col0" >-0.0250</td>
#       <td id="T_0da10_row9_col1" class="data row9 col1" > NA</td>
#       <td id="T_0da10_row9_col2" class="data row9 col2" > NA</td>
#       <td id="T_0da10_row9_col3" class="data row9 col3" ></td>
#       <td id="T_0da10_row9_col4" class="data row9 col4" >-0.03</td>
#       <td id="T_0da10_row9_col5" class="data row9 col5" >fixed value</td>
#     </tr>
#     <tr>
#       <th id="T_0da10_level1_row10" class="row_heading level1 row10" >Time_NM</th>
#       <td id="T_0da10_row10_col0" class="data row10 col0" >-0.0249</td>
#       <td id="T_0da10_row10_col1" class="data row10 col1" > 0.000256</td>
#       <td id="T_0da10_row10_col2" class="data row10 col2" >-97.48</td>
#       <td id="T_0da10_row10_col3" class="data row10 col3" >***</td>
#       <td id="T_0da10_row10_col4" class="data row10 col4" > 0.00</td>
#       <td id="T_0da10_row10_col5" class="data r

# %%
m.estimation_statistics()
# Out:
# <xmle.Elem 'div' with 1 children>

# %%
# Report
report = larch.Reporter(title=m.title)
report << '## Data Statistics' << m.dataframes.data_co.statistics()
report << '## Choice Table Summary' << m.dataframes.choice_avail_summary()
report << "## Utility Functions" << m.utility_functions()
report << '## Parameter Summary' << m.parameter_summary()
report << "## Estimation Statistics" << m.estimation_statistics()
report.save(
    '.\Oahu_VisMC_HBRec.html',
    overwrite=True,
    metadata=m,
)
# Out:
# '.\\Oahu_VisMC_HBRec.html'
